# %%
import os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
project_dir = r"C:\Users\Samar mubark\Desktop\flight_price_prediction"
data_dir = "data"

# %%
os.path.join(project_dir, data_dir , f"flight_price.csv")
# Out:
# 'C:\\Users\\Samar mubark\\Desktop\\flight_price_prediction\\data\\flight_price.csv'

# %%
def get_data(name):
    file_name = f"{name}.csv"
    file_path = os.path.join(project_dir, data_dir , file_name)
    return pd.read_csv(file_path)

# %%
flights = get_data("flight_price")
flights
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                      ...      ...           ...      ...         ...
# 10678              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20         11:20       3h    non-stop
# 10681              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 0             No info   3897
# 1             No info   7662
# 2             No info  13882
# 3             No info   6218
# 4             No info  13302
# ...               ...    ...
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753
#
# [10683 rows x 11 columns]

# %%
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
flights.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
flights.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# dtype: object

# %%
flights.duplicated(keep=False).sum()
# Out:
# 415

# %%
flights.loc[flights.duplicated(keep=False)].sort_values(["Airline","Date_of_Journey","Source","Destination","Route"])
# Out:
#         Airline Date_of_Journey    Source Destination                  Route  \
# 6321  Air India      01/03/2019  Banglore   New Delhi  BLR → BOM → AMD → DEL
# 9848  Air India      01/03/2019  Banglore   New Delhi  BLR → BOM → AMD → DEL
# 572   Air India      03/03/2019  Banglore   New Delhi              BLR → DEL
# 8168  Air India      03/03/2019  Banglore   New Delhi              BLR → DEL
# 1495  Air India       1/04/2019   Kolkata    Banglore  CCU → DEL → COK → BLR
# ...         ...             ...       ...         ...                    ...
# 2692   SpiceJet      24/03/2019  Banglore   New Delhi              BLR → DEL
# 2870   SpiceJet      24/03/2019  Banglore   New Delhi              BLR → DEL
# 3711   SpiceJet      24/03/2019  Banglore   New Delhi              BLR → DEL
# 2634    Vistara      24/03/2019  Banglore   New Delhi              BLR → DEL
# 5470    Vistara      24/03/2019  Banglore   New Delhi              BLR → DEL
#
#      Dep_Time  Arrival_Time Duration Total_Stops  \
# 6321    08:50  23:55 02 Mar   39h 5m     2 stops
# 9848    08:50  23:55 02 Mar   39h 5m     2 stops
# 572     21:10         23:55   2h 45m    non-stop
# 8168    21:10         23:55   2h 45m    non-stop
# 1495    10:00  01:20 02 Apr  15h 20m     2 stops
# ...       ...           ...      ...         ...
# 2692    05:45         08:35   2h 50m    non-stop
# 2870    05:45         08:35   2h 50m    non-stop
# 3711    20:30         23:20   2h 50m    non-stop
# 2634    11:30         14:10   2h 40m    non-stop
# 5470    11:30         14:10   2h 40m    non-stop
#
#                    Additional_Info  Price
# 6321                       No info  17135
# 9848                       No info  17135
# 572                        No info   7591
# 8168                       No info   7591
# 1495                       No info  10408
# ...                            ...    ...
# 2692  No check-in baggage included   4273
# 2870  No check-in baggage included   4273
# 3711  No check-in baggage included   3873
# 2634                       No info   5403
# 5470                       No info   5403
#
# [415 rows x 11 columns]

# %% [markdown]
# # upon thorough checking i found out there are 415 duplicate rows which should be removed

# %% [markdown]
# ## will now create function for cleaning data

# %%
def convert_to_minutes(ser):
    return(ser
           .str.split(" " ,  expand =True)
           .set_axis(["hour","minutes"], axis = 1)
           .assign(hour = lambda df_: (
           df_
           .hour
           .str.replace("h", "")
           .astype(int)
           .mul(60)
           ),
            minutes = lambda df_:(
            df_
            .minutes
            .str.replace("m","")
            .fillna("0")
            .astype(int)
            
            )     )
           
           .sum(axis=1)
           )

# %%
def clean(df):
    return(
    df.drop(index=[6474])
        .assign(**{
        col: df[col].str.strip()
        for col in df.select_dtypes(include ="O").columns
    })
    .rename(columns = str.lower)
    .assign(
        airline = lambda df_ : (df_
                               .airline
                               .str.replace("Premium economy","")
                                
                               .str.replace("Business", "")
                               .str.title())
        ,
        date_of_journey = lambda df_ : pd.to_datetime(df_.date_of_journey, dayfirst = True),
        dep_time = lambda  df_ : pd.to_datetime(df_.dep_time).dt.time,
        arrival_time =lambda df_ :pd.to_datetime(df_.arrival_time).dt.time,
        duration = lambda df_ : df_.duration.pipe(convert_to_minutes),
        total_stops = lambda df_ : (
        df_
        .total_stops
        .replace("non stop" ,"0")
        .str.replace("stops?","", regex = True)
        .pipe(lambda ser: pd.to_numeric(ser))
        
        
        ),additional_info = lambda df_ : pd.additional_info.replace("No info","No Info")
        
    
    
    
    )
    .drop(columns="route")
    
    )

# %%
clean(flights)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\_libs\lib.pyx:2369, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "non-"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[118], line 1
# ----> 1 clean(flights)
#
# Cell In[117], line 3, in clean(df)
#       1 def clean(df):
#       2     return(
# ----> 3     df.drop(index=[6474])
#       4         .assign(**{
#       5         col: df[col].str.strip()
#       6         for col in df.select_dtypes(include ="O").columns
#       7     })
#       8     .rename(columns = str.lower)
#       9     .assign(
#      10         airline = lambda df_ : (df_
#      11                                .airline
#      12                                .str.replace("Premium economy","")
#      13
#      14                                .str.replace("Business", "")
#      15                                .str.title())
#      16         ,
#      17         date_of_journey = lambda df_ : pd.to_datetime(df_.date_of_journey, dayfirst = True),
#      18         dep_time = lambda  df_ : pd.to_datetime(df_.dep_time).dt.time,
#      19         arrival_time =lambda df_ :pd.to_datetime(df_.arrival_time).dt.time,
#      20         duration = lambda df_ : df_.duration.pipe(convert_to_minutes),
#      21         total_stops = lambda df_ : (
#      22         df_
#      23         .total_stops
#      24         .replace("non stop" ,"0")
#      25         .str.replace("stops?","", regex = True)
#      26         .pipe(lambda ser: pd.to_numeric(ser))
#      27
#      28
#      29         ),additional_info = lambda df_ : pd.additional_info.replace("No info","No Info")
#      30
#      31
#      32
#      33
#      34     )
#      35     .drop(columns="route")
#      36
#      37     )
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\frame.py:4889, in DataFrame.assign(self, **kwargs)
#    4886 data = self.copy()
#    4888 for k, v in kwargs.items():
# -> 4889     data[k] = com.apply_if_callable(v, data)
#    4890 return data
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\common.py:374, in apply_if_callable(maybe_callable, obj, **kwargs)
#     363 """
#     364 Evaluate possibly callable input using obj and kwargs if it is callable,
#     365 otherwise return as it is.
#    (...)
#     371 **kwargs
#     372 """
#     373 if callable(maybe_callable):
# --> 374     return maybe_callable(obj, **kwargs)
#     376 return maybe_callable
#
# Cell In[117], line 26, in clean.<locals>.<lambda>(df_)
#       1 def clean(df):
#       2     return(
#       3     df.drop(index=[6474])
#       4         .assign(**{
#       5         col: df[col].str.strip()
#       6         for col in df.select_dtypes(include ="O").columns
#       7     })
#       8     .rename(columns = str.lower)
#       9     .assign(
#      10         airline = lambda df_ : (df_
#      11                                .airline
#      12                                .str.replace("Premium economy","")
#      13
#      14                                .str.replace("Business", "")
#      15                                .str.title())
#      16         ,
#      17         date_of_journey = lambda df_ : pd.to_datetime(df_.date_of_journey, dayfirst = True),
#      18         dep_time = lambda  df_ : pd.to_datetime(df_.dep_time).dt.time,
#      19         arrival_time =lambda df_ :pd.to_datetime(df_.arrival_time).dt.time,
#      20         duration = lambda df_ : df_.duration.pipe(convert_to_minutes),
#      21         total_stops = lambda df_ : (
#      22         df_
#      23         .total_stops
#      24         .replace("non stop" ,"0")
#      25         .str.replace("stops?","", regex = True)
# ---> 26         .pipe(lambda ser: pd.to_numeric(ser))
#      27
#      28
#      29         ),additional_info = lambda df_ : pd.additional_info.replace("No info","No Info")
#      30
#      31
#      32
#      33
#      34     )
#      35     .drop(columns="route")
#      36
#      37     )
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\generic.py:5839, in NDFrame.pipe(self, func, *args, **kwargs)
#    5781 @final
#    5782 @doc(klass=_shared_doc_kwargs["klass"])
#    5783 def pipe(
#    (...)
#    5787     **kwargs,
#    5788 ) -> T:
#    5789     r"""
#    5790     Apply chainable functions that expect Series or DataFrames.
#    5791
#    (...)
#    5837     ...  )  # doctest: +SKIP
#    5838     """
# -> 5839     return com.pipe(self, func, *args, **kwargs)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\common.py:513, in pipe(obj, func, *args, **kwargs)
#     511     return func(*args, **kwargs)
#     512 else:
# --> 513     return func(obj, *args, **kwargs)
#
# Cell In[117], line 26, in clean.<locals>.<lambda>.<locals>.<lambda>(ser)
#       1 def clean(df):
#       2     return(
#       3     df.drop(index=[6474])
#       4         .assign(**{
#       5         col: df[col].str.strip()
#       6         for col in df.select_dtypes(include ="O").columns
#       7     })
#       8     .rename(columns = str.lower)
#       9     .assign(
#      10         airline = lambda df_ : (df_
#      11                                .airline
#      12                                .str.replace("Premium economy","")
#      13
#      14                                .str.replace("Business", "")
#      15                                .str.title())
#      16         ,
#      17         date_of_journey = lambda df_ : pd.to_datetime(df_.date_of_journey, dayfirst = True),
#      18         dep_time = lambda  df_ : pd.to_datetime(df_.dep_time).dt.time,
#      19         arrival_time =lambda df_ :pd.to_datetime(df_.arrival_time).dt.time,
#      20         duration = lambda df_ : df_.duration.pipe(convert_to_minutes),
#      21         total_stops = lambda df_ : (
#      22         df_
#      23         .total_stops
#      24         .replace("non stop" ,"0")
#      25         .str.replace("stops?","", regex = True)
# ---> 26         .pipe(lambda ser: pd.to_numeric(ser))
#      27
#      28
#      29         ),additional_info = lambda df_ : pd.additional_info.replace("No info","No Info")
#      30
#      31
#      32
#      33
#      34     )
#      35     .drop(columns="route")
#      36
#      37     )
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\tools\numeric.py:185, in to_numeric(arg, errors, downcast)
#     183 coerce_numeric = errors not in ("ignore", "raise")
#     184 try:
# --> 185     values, _ = lib.maybe_convert_numeric(
#     186         values, set(), coerce_numeric=coerce_numeric
#     187     )
#     188 except (ValueError, TypeError):
#     189     if errors == "raise":
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\_libs\lib.pyx:2411, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "non-" at position 0
